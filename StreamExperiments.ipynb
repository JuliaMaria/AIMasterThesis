# %%
# %matplotlib notebook

# %%
import numpy as np
from river import tree
from river import synth
from river.drift import PageHinkley
from river import evaluate
from river import metrics

# %%
from river import ensemble
from river import linear_model
from river import tree
from river import naive_bayes

# %%
dataset = synth.ConceptDriftStream(stream=synth.SEA(seed=42, variant=0), drift_stream=synth.SEA(seed=42, variant=1), seed=1, position=5, width=2)

# %%
metric = metrics.F1()

# %% [markdown]
# # Example with trees

# %%
model = tree.HoeffdingTreeClassifier()

evaluate.progressive_val_score(dataset, model, metric, print_every=200)
# Out:
# [200] F1: 90.24%
# [400] F1: 92.58%
# [600] F1: 93.95%
# [800] F1: 94.67%
# [1,000] F1: 94.99%
# [1,200] F1: 95.19%
# [1,400] F1: 95.23%
# [1,600] F1: 95.23%
# [1,800] F1: 95.26%
# [2,000] F1: 95.51%
# [2,200] F1: 95.33%
# [2,400] F1: 95.34%
# [2,600] F1: 95.40%
# [2,800] F1: 95.40%
# [3,000] F1: 95.49%
# [3,200] F1: 95.51%
# [3,400] F1: 95.44%
# [3,600] F1: 94.99%
# [3,800] F1: 94.88%
# [4,000] F1: 94.84%
# [4,200] F1: 94.84%
# [4,400] F1: 94.85%
# [4,600] F1: 94.75%
# [4,800] F1: 94.61%
# [5,000] F1: 94.60%
# [5,200] F1: 94.64%
# [5,400] F1: 94.66%
# [5,600] F1: 94.57%
# [5,800] F1: 94.62%
# [6,000] F1: 94.61%
# [6,200] F1: 94.60%
# [6,400] F1: 94.65%
# [6,600] F1: 94.70%
# [6,800] F1: 94.78%
# [7,000] F1: 94.84%
# [7,200] F1: 94.87%
# [7,400] F1: 94.88%
# [7,600] F1: 94.94%
# [7,800] F1: 94.93%
# [8,000] F1: 95.00%
# [8,200] F1: 95.00%
# [8,400] F1: 95.03%
# [8,600] F1: 95.12%
# [8,800] F1: 95.18%
# [9,000] F1: 95.21%
# [9,200] F1: 95.24%
# [9,400] F1: 95.33%
# [9,600] F1: 95.36%
# [9,800] F1: 95.41%
# [10,000] F1: 95.44%
# [10,200] F1: 95.48%
# [10,400] F1: 95.54%
# [10,600] F1: 95.56%
# [10,800] F1: 95.62%
# [11,000] F1: 95.67%
# [11,200] F1: 95.68%
# [11,400] F1: 95.73%
# [11,600] F1: 95.75%
# [11,800] F1: 95.74%
# [12,000] F1: 95.80%
# [12,200] F1: 95.84%
# [12,400] F1: 95.89%
# [12,600] F1: 95.89%
# [12,800] F1: 95.91%
# [13,000] F1: 95.95%
# [13,200] F1: 95.99%
# [13,400] F1: 96.03%
# [13,600] F1: 96.04%
# [13,800] F1: 96.06%
# [14,000] F1: 96.09%
# [14,200] F1: 96.09%
# [14,400] F1: 96.09%
# [14,600] F1: 96.10%
# [14,800] F1: 96.11%
# [15,000] F1: 96.13%
# [15,200] F1: 96.15%
# [15,400] F1: 96.16%
# [15,600] F1: 96.19%
# [15,800] F1: 96.19%

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bfa8312af4f0> in <module>
# ----> 1 evaluate.progressive_val_score(dataset, model, metric, print_every=200)
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/evaluate/progressive_validation.py in progressive_val_score(dataset, model, metric, moment, delay, print_every, show_time, show_memory, **print_kwargs)
#     238     )
#     239
# --> 240     for checkpoint in checkpoints:
#     241
#     242         msg = f"[{checkpoint['Step']:,d}] {metric}"
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/evaluate/progressive_validation.py in _progressive_validation(dataset, model, metric, checkpoints, moment, delay, measure_time, measure_memory)
#      55             metric.update(y_true=y, y_pred=y_pred)
#      56         if model._supervised:
# ---> 57             model.learn_one(x=x, y=y, **kwargs)
#      58         else:
#      59             model.learn_one(x=x, **kwargs)
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/tree/hoeffding_tree_classifier.py in learn_one(self, x, y, sample_weight)
#     350             path = iter(self._root.walk(x, until_leaf=False))
#     351             while True:
# --> 352                 aux = next(path, None)
#     353                 if aux is None:
#     354                     break
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/tree/base.py in walk(self, x, until_leaf)
#      48         yield self
#      49         try:
# ---> 50             yield from self.next(x).walk(x, until_leaf)
#      51         except KeyError:
#      52             if until_leaf:
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/tree/base.py in walk(self, x, until_leaf)
#      48         yield self
#      49         try:
# ---> 50             yield from self.next(x).walk(x, until_leaf)
#      51         except KeyError:
#      52             if until_leaf:
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/tree/base.py in walk(self, x, until_leaf)
#      48         yield self
#      49         try:
# ---> 50             yield from self.next(x).walk(x, until_leaf)
#      51         except KeyError:
#      52             if until_leaf:
#
# KeyboardInterrupt:

# %% [markdown]
# # Drift detection

# %%
# Stream with binary labels
classes = 2
features = len(list(dataset.take(1))[0][0].keys())

# %%
phs = [[PageHinkley() for i in range(features)] for j in range(classes)]

# %%
# Only works for one-dimensional streams, each class and feature needs to be considered separately
samples = dataset.take(2000)
for i, sample in enumerate(samples):
    item = sample[0]
    label = int(sample[1])
    in_drifts = np.array(
        [
            ph.update(item[feature])[0] 
            for feature, ph in enumerate(phs[label])
        ]
    )
    if in_drifts.any():
        print('Change detected in data: ' + str(item) + ', of index: ' + str(i) + ', of class: ' + str(label) + ', in features: ' + str(in_drifts))
# Out:
# Change detected in data: {0: 7.5347512505938585, 1: 8.534479505691046, 2: 9.534303384701063}, of index: 164, of class: 1, in features: [False  True False]
# Change detected in data: {0: 0.09397431454871041, 1: 8.046330769751464, 2: 9.01209423598883}, of index: 297, of class: 0, in features: [False  True False]
# Change detected in data: {0: 6.777644586233595, 1: 7.20928376670709, 2: 6.591815403167537}, of index: 309, of class: 1, in features: [False False  True]
# Change detected in data: {0: 8.289589728944645, 1: 7.387746721294828, 2: 6.854144402775763}, of index: 437, of class: 1, in features: [False False  True]
# Change detected in data: {0: 1.7578870753886255, 1: 9.19634811850934, 2: 9.9717180308851}, of index: 612, of class: 1, in features: [False False  True]
# Change detected in data: {0: 8.957647816143137, 1: 7.785382813284745, 2: 0.5859123027811852}, of index: 964, of class: 1, in features: [ True False False]
# Change detected in data: {0: 8.341081186760043, 1: 2.5788635998777654, 2: 9.108044857315942}, of index: 1036, of class: 1, in features: [False False  True]
# Change detected in data: {0: 2.494902613242793, 1: 4.5644866712808065, 2: 9.180310693411162}, of index: 1061, of class: 0, in features: [False  True False]
# Change detected in data: {0: 8.299834819551444, 1: 9.114863770737387, 2: 7.046290688927877}, of index: 1223, of class: 1, in features: [False  True False]
# Change detected in data: {0: 6.626784893786967, 1: 8.479818401038665, 2: 8.065400569278985}, of index: 1299, of class: 1, in features: [False False  True]
# Change detected in data: {0: 1.2196155618577076, 1: 7.681456708511898, 2: 2.4896236050723406}, of index: 1476, of class: 0, in features: [False  True False]
# Change detected in data: {0: 9.736818888990879, 1: 7.557429355712851, 2: 4.65695363043169}, of index: 1721, of class: 1, in features: [ True False False]
# Change detected in data: {0: 6.208748388565411, 1: 5.479490172790012, 2: 9.738917312202949}, of index: 1734, of class: 1, in features: [False False  True]
# Change detected in data: {0: 8.702777358497256, 1: 0.11863040095509647, 2: 9.272225260534066}, of index: 1801, of class: 0, in features: [ True False False]
# Change detected in data: {0: 6.433381669688948, 1: 9.126092228411265, 2: 7.154003177508432}, of index: 1828, of class: 1, in features: [False  True False]
# Change detected in data: {0: 8.342502922697223, 1: 4.493072775496105, 2: 9.958336280019452}, of index: 1849, of class: 1, in features: [ True False False]
# Change detected in data: {0: 4.744128398412081, 1: 1.7632381737053082, 2: 6.701426351269561}, of index: 1883, of class: 0, in features: [False False  True]
# Change detected in data: {0: 7.3849498142410495, 1: 9.756010361567812, 2: 3.312806460801061}, of index: 1963, of class: 1, in features: [False  True False]

# %% [markdown]
# # Example with ensembles

# %%
model = ensemble.VotingClassifier([
        linear_model.LogisticRegression(),
        tree.HoeffdingTreeClassifier(),
        naive_bayes.GaussianNB()
])

evaluate.progressive_val_score(dataset, model, metric, print_every=200)
# Out:
# [200] F1: 97.46%
# [400] F1: 97.44%
# [600] F1: 97.41%
# [800] F1: 97.39%
# [1,000] F1: 97.36%
# [1,200] F1: 97.35%
# [1,400] F1: 97.34%
# [1,600] F1: 97.31%
# [1,800] F1: 97.28%
# [2,000] F1: 97.27%
# [2,200] F1: 97.23%
# [2,400] F1: 97.21%
# [2,600] F1: 97.20%
# [2,800] F1: 97.19%
# [3,000] F1: 97.18%
# [3,200] F1: 97.18%
# [3,400] F1: 97.15%
# [3,600] F1: 97.12%
# [3,800] F1: 97.09%
# [4,000] F1: 97.08%
# [4,200] F1: 97.07%
# [4,400] F1: 97.06%
# [4,600] F1: 97.03%
# [4,800] F1: 97.00%
# [5,000] F1: 96.99%
# [5,200] F1: 96.99%
# [5,400] F1: 96.98%
# [5,600] F1: 96.97%
# [5,800] F1: 96.96%
# [6,000] F1: 96.95%
# [6,200] F1: 96.94%
# [6,400] F1: 96.94%
# [6,600] F1: 96.93%
# [6,800] F1: 96.93%
# [7,000] F1: 96.94%
# [7,200] F1: 96.93%
# [7,400] F1: 96.92%
# [27,000] F1: 97.27%
# [27,200] F1: 97.28%
# [27,400] F1: 97.28%
# [27,600] F1: 97.28%
# [27,800] F1: 97.29%
# [28,000] F1: 97.29%
# [28,200] F1: 97.29%
# [28,400] F1: 97.30%
# [28,600] F1: 97.30%
# [28,800] F1: 97.31%
# [29,000] F1: 97.31%
# [29,200] F1: 97.32%
# [29,400] F1: 97.32%
# [29,600] F1: 97.32%
# [29,800] F1: 97.33%
# [30,000] F1: 97.33%
# [30,200] F1: 97.34%
# [30,400] F1: 97.34%
# [30,600] F1: 97.34%
# [30,800] F1: 97.35%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-01a4975e94a5> in <module>
#       5 ])
#       6
# ----> 7 evaluate.progressive_val_score(dataset, model, metric, print_every=200)
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/evaluate/progressive_validation.py in progressive_val_score(dataset, model, metric, moment, delay, print_every, show_time, show_memory, **print_kwargs)
#     238     )
#     239
# --> 240     for checkpoint in checkpoints:
#     241
#     242         msg = f"[{checkpoint['Step']:,d}] {metric}"
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/evaluate/progressive_validation.py in _progressive_validation(dataset, model, metric, checkpoints, moment, delay, measure_time, measure_memory)
#      47         # Question
#      48         if y is None:
# ---> 49             preds[i] = pred_func(x=x, **kwargs)
#      50             continue
#      51
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/ensemble/voting.py in predict_one(self, x)
#      70             votes = ({model.predict_one(x): 1} for model in self)
#      71         agg = collections.Counter()
# ---> 72         for vote in votes:
#      73             agg.update(vote)
#      74         return agg.most_common(1)[0][0]
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/ensemble/voting.py in <genexpr>(.0)
#      66     def predict_one(self, x):
#      67         if self.use_probabilities:
# ---> 68             votes = (model.predict_proba_one(x) for model in self)
#      69         else:
#      70             votes = ({model.predict_one(x): 1} for model in self)
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/naive_bayes/gaussian.py in predict_proba_one(self, x)
#      56     def predict_proba_one(self, x):
#      57         """Return probabilities using the log-likelihoods."""
# ---> 58         jll = self.joint_log_likelihood(x)
#      59         if not jll:
#      60             return {}
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/naive_bayes/gaussian.py in joint_log_likelihood(self, x)
#      66
#      67     def joint_log_likelihood(self, x):
# ---> 68         return {
#      69             c: math.log(self.p_class(c))
#      70             + sum(math.log(10e-10 + gaussians[i].pdf(xi)) for i, xi in x.items())
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/naive_bayes/gaussian.py in <dictcomp>(.0)
#      68         return {
#      69             c: math.log(self.p_class(c))
# ---> 70             + sum(math.log(10e-10 + gaussians[i].pdf(xi)) for i, xi in x.items())
#      71             for c, gaussians in self.gaussians.items()
#      72         }
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/naive_bayes/gaussian.py in <genexpr>(.0)
#      68         return {
#      69             c: math.log(self.p_class(c))
# ---> 70             + sum(math.log(10e-10 + gaussians[i].pdf(xi)) for i, xi in x.items())
#      71             for c, gaussians in self.gaussians.items()
#      72         }
#
# /Applications/anaconda3/envs/MasterThesis/lib/python3.8/site-packages/river/proba/gaussian.py in pdf(self, x)
#      51         return self
#      52
# ---> 53     def pdf(self, x):
#      54         var = self._var.get()
#      55         if var:
#
# KeyboardInterrupt:
